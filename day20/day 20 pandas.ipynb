# %%
import pandas as pd

x = pd.Series(["ram","hari","gita","sita","madan"])
x
# Out:
# 0      ram
# 1     hari
# 2     gita
# 3     sita
# 4    madan
# dtype: object

# %%
x = pd.Series(["ram","hari","gita","sita","madan"], index=[9,7,6,5,4])
x
# Out:
# 9      ram
# 7     hari
# 6     gita
# 5     sita
# 4    madan
# dtype: object

# %%
data = {
    "Name": ["Ram", "Shyam", "Hari"],
    "Age": [20, 21, 22],
    "City": ["Kathmandu", "Pokhara", "Lalitpur"]
}

df = pd.DataFrame(data)
df
# Out:
#     Name  Age       City
# 0    Ram   20  Kathmandu
# 1  Shyam   21    Pokhara
# 2   Hari   22   Lalitpur

# %%
df.head()     # first 5 rows
df.tail()     # last 5 rows
df.shape      # (rows, columns)
df.columns    # column names
df.info()     # data types
df.describe() # statistics
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   City    3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes
#         Age
# count   3.0
# mean   21.0
# std     1.0
# min    20.0
# 25%    20.5
# 50%    21.0
# 75%    21.5
# max    22.0

# %%
df[["Name", "Age"]]
# Out:
#     Name  Age
# 0    Ram   20
# 1  Shyam   21
# 2   Hari   22

# %% [markdown]
#  loc = label-based indexing
#
# df.loc[row_label, column_label]
#
#  iloc = integer position-based indexing
#
# df.iloc[row_position, column_position]

# %%
data = {
    "Name": ["Ram", "Shyam", "Hari"],
    "Age": [20, 21, 22],
    "City": ["Kathmandu", "Pokhara", "Lalitpur"]
}

df = pd.DataFrame(data)
df
# Out:
#     Name  Age       City
# 0    Ram   20  Kathmandu
# 1  Shyam   21    Pokhara
# 2   Hari   22   Lalitpur

# %%
x= df.loc[1]
x
# Out:
# Name      Shyam
# Age          21
# City    Pokhara
# Name: 1, dtype: object

# %%
df.loc[:,"City"]
# Out:
# 0    Kathmandu
# 1      Pokhara
# 2     Lalitpur
# Name: City, dtype: object

# %%
df.loc[[0,1],["Name","Age"]]
# Out:
#     Name  Age
# 0    Ram   20
# 1  Shyam   21

# %%
df.iloc[:,1]
# Out:
# 0    20
# 1    21
# 2    22
# Name: Age, dtype: int64

# %%
import matplotlib.pyplot as plt

x= [3,4,5,6,3,2,1]
y=[21,34,56,33,87,95,66]

plt.plot(x,y)
