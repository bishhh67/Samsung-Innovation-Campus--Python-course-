# %% [markdown]
# Merge Sort

# %%
data = sorted([3,6,8,3,2,1,2])

# %%
def merge_sort(arr):
    if len(arr) <= 1:
        return arr 

    mid = len(arr) // 2
    left = merge_sort(arr[:mid])
    right = merge_sort(arr[mid:])

    return merge(left, right)


def merge(left,right):
    result=[]
    i=0
    j=0

    while i<len(left) and i<len(right):
        if left[i] < right[j]:
            result.append(left[i])
            i+=1
        else:
            result.append(right[j])
            j+=1


    result.extend(left[i:])
    result.extend(right[j:])

    return result
    
arr = [38, 27, 43, 3, 9, 82, 10]
sorted_arr = merge_sort(arr)
print(sorted_arr)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 32
#      29     return result
#      31 arr = [38, 27, 43, 3, 9, 82, 10]
# ---> 32 sorted_arr = merge_sort(arr)
#      33 print(sorted_arr)
#
# Cell In[13], line 7, in merge_sort(arr)
#       5 mid = len(arr) // 2
#       6 left = merge_sort(arr[:mid])
# ----> 7 right = merge_sort(arr[mid:])
#       9 return merge(left, right)
#
# Cell In[13], line 7, in merge_sort(arr)
#       5 mid = len(arr) // 2
#       6 left = merge_sort(arr[:mid])
# ----> 7 right = merge_sort(arr[mid:])
#       9 return merge(left, right)
#
# Cell In[13], line 9, in merge_sort(arr)
#       6 left = merge_sort(arr[:mid])
#       7 right = merge_sort(arr[mid:])
# ----> 9 return merge(left, right)
#
# Cell In[13], line 18, in merge(left, right)
#      15 j=0
#      17 while i<len(left) and i<len(right):
# ---> 18     if left[i] < right[j]:
#      19         result.append(left[i])
#      20         i+=1
#
# IndexError: list index out of range

# %%
result.append(left[i])
            i += 1
        else:
