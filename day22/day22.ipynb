# %%
denominations= [1000,500,100,50,20,10,2,1]

def get(amount):
    change= {}
    for denom in denominations:
        t = amount//denom
        change[denomination] = t 
        amount = amount%denom

    return change 

get_change(223)
# Out:
# {1000: 2, 500: 0, 100: 0, 50: 0, 20: 1, 10: 0, 2: 1, 1: 1}

# %%
denominations={
    1000:5,
    500:5,
    100:50,
    50:3,
    20:1,
    10:20,
    5:1,
    2:10,
    1:11
}
def get_change(amnt):
    change={}
    for denom,number in denominations.items():
        times = amnt//denom
        if number ==times:
            
            change[denom] = times
            amnt=amnt%denom
        elif number !=0:
            change[denom]=number
            amnt -=number *denom
            denominations[denom]=0
        else:
            continue 
        return change

get_change(1010)
# Out:
# {1000: 5}
